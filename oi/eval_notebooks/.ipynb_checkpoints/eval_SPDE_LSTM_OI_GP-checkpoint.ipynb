# %% [markdown]
# # Prior SPDE + LSTM solver Evaluation Notebook (SPDE-based GP)

# %% [markdown]
# ## 1. Import tools and change directory

# %%
from utils_GP import *
import pandas as pd
import os

# %%
os.chdir("/gpfswork/rech/yrf/uba22to/4dvarnet-core")
print(os.getcwd())
# Out:
# /gpfsdswork/projects/rech/yrf/uba22to/4dvarnet-core

# %% [markdown]
# ## 2. Run the code

# %%
#!HYDRA_FULL_ERROR=1 python hydra_main.py xp=oi_gp_spde_learn_params file_paths=dc_gp entrypoint=run entrypoint.max_epochs=50
# !HYDRA_FULL_ERROR=1 python hydra_main.py xp=oi_gp_spde_learn_params file_paths=dc_gp entrypoint=run entrypoint.max_epochs=30
# Out:
# /gpfsdswork/projects/rech/yrf/uba22to/4dvarnet-core/hydra_main.py:212: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path='hydra_config', config_name='main')
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/upgrades/1.1_to_1.2/changes_to_job_working_dir for more information.
#   ret = run_job(
# Global seed set to 0
# file_paths:
#   obs_path: /gpfswork/rech/yrf/uba22to/4dvarnet-core/oi/data/SPDE_diffusion_dataset.nc
#   gt_path: /gpfswork/rech/yrf/uba22to/4dvarnet-core/oi/data/SPDE_diffusion_dataset.nc
#   spde_params_path: /gpfswork/rech/yrf/uba22to/4dvarnet-core/oi/data/SPDE_diffusion_dataset.nc
# entrypoint:
#   _target_: hydra_main.FourDVarNetHydraRunner.run
#   max_epochs: 30
#   progress_bar_refresh_rate: 5
# params:
#   files_cfg:
#     obs_path: ${file_paths.obs_path}
#     obs_var: 'y'
#     gt_path: ${file_paths.gt_path}
#     gt_var: x
#     spde_params_path: ${file_paths.spde_params_path}
#   iter_update:
#   - 0
#   - 20
#   - 40
#   - 60
#   - 100
#   - 150
#   - 800
#   nb_grad_update:
#   - 20
#   - 20
#   - 20
#   - 20
#   - 20
#   - 20
#   - 50
#   - 50
#   - 50
#   lr_update:
#   - 0.001
#   - 0.0001
#   - 0.001
#   - 0.0001
#   - 0.0001
#   - 1.0e-05
#   - 1.0e-05
#   - 1.0e-06
#   - 1.0e-07
#   k_batch: 1
#   n_grad: 5
#   dT: 5
#   dx: 1
#   W: 100
#   resize_factor: 1
#   shapeData:
#   - 5
#   - 100
#   - 100
#   dW: 3
#   dW2: 1
#   sS: 4
#   nbBlocks: 1
#   Nbpatches: 1
#   stochastic: false
#   size_ensemble: 1
#   animate: true
#   supervised: true
#   estim_parameters: true
#   DimAE: 25
#   dim_grad_solver: 70
#   dropout: 0.25
#   dropout_phi_r: 0.0
#   alpha_proj: 0.5
#   alpha_sr: 0.5
#   alpha_lr: 0.5
#   alpha_mse_ssh: 10.0
#   alpha_mse_gssh: 1.0
#   sigNoise: 0.0
#   flagSWOTData: true
#   rnd1: 0
#   rnd2: 100
#   dwscale: 1
#   UsePriodicBoundary: false
#   InterpFlag: false
#   automatic_optimization: true
#   ckpt_name: modelGP_{epoch:02d}-{val_loss:.2f}
#   norm_obs: l2
#   norm_prior: l2
#   diff_only: true
# datamodule:
#   dim_range:
#     lat:
#       _target_: builtins.slice
#       _args_:
#       - 0
#       - 100
#     lon:
#       _target_: builtins.slice
#       _args_:
#       - 0
#       - 100
#   _target_: oi.dataloading_gp.FourDVarNetDataModule
#   slice_win:
#     lat: 100
#     lon: 100
#     time: 5
#   strides:
#     lat: 100
#     lon: 100
#     time: 1
#   train_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2012-10-01'
#     - '2012-11-20'
#   - _target_: builtins.slice
#     _args_:
#     - '2013-02-07'
#     - '2013-09-10'
#   test_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2013-01-03'
#     - '2013-01-27'
#   val_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2012-11-30'
#     - '2012-12-24'
#   obs_path: ${params.files_cfg.obs_path}
#   obs_var: ${params.files_cfg.obs_var}
#   gt_path: ${params.files_cfg.gt_path}
#   gt_var: ${params.files_cfg.gt_var}
#   dl_kwargs:
#     batch_size: 2
#     num_workers: 2
#   resize_factor: 1
# lit_mod_cls: oi.lit_model_spde.LitModel
# xp_name: oi_gp_spde_learn_params
# seed: 0
#
# Using current oi.metrics
# [2022-05-17 17:24:14,608][cartopy_userconfig][INFO] - Setting cartopy.config["pre_existing_data_dir"] to /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/share/cartopy. Don't worry, this is probably intended behaviour to avoid failing downloads of geological data behind a firewall.
# file_paths:
#   obs_path: /gpfswork/rech/yrf/uba22to/4dvarnet-core/oi/data/SPDE_diffusion_dataset.nc
#   gt_path: /gpfswork/rech/yrf/uba22to/4dvarnet-core/oi/data/SPDE_diffusion_dataset.nc
#   spde_params_path: /gpfswork/rech/yrf/uba22to/4dvarnet-core/oi/data/SPDE_diffusion_dataset.nc
# entrypoint:
#   _target_: hydra_main.FourDVarNetHydraRunner.run
#   max_epochs: 30
#   progress_bar_refresh_rate: 5
# params:
#   files_cfg:
#     obs_path: ${file_paths.obs_path}
#     obs_var: 'y'
#     gt_path: ${file_paths.gt_path}
#     gt_var: x
#     spde_params_path: ${file_paths.spde_params_path}
#   iter_update:
#   - 0
#   - 20
#   - 40
#   - 60
#   - 100
#   - 150
#   - 800
#   nb_grad_update:
#   - 20
#   - 20
#   - 20
#   - 20
#   - 20
#   - 20
#   - 50
#   - 50
#   - 50
#   lr_update:
#   - 0.001
#   - 0.0001
#   - 0.001
#   - 0.0001
#   - 0.0001
#   - 1.0e-05
#   - 1.0e-05
#   - 1.0e-06
#   - 1.0e-07
#   k_batch: 1
#   n_grad: 5
#   dT: 5
#   dx: 1
#   W: 100
#   resize_factor: 1
#   shapeData:
#   - 5
#   - 100
#   - 100
#   dW: 3
#   dW2: 1
#   sS: 4
#   nbBlocks: 1
#   Nbpatches: 1
#   stochastic: false
#   size_ensemble: 1
#   animate: true
#   supervised: true
#   estim_parameters: true
#   DimAE: 25
#   dim_grad_solver: 70
#   dropout: 0.25
#   dropout_phi_r: 0.0
#   alpha_proj: 0.5
#   alpha_sr: 0.5
#   alpha_lr: 0.5
#   alpha_mse_ssh: 10.0
#   alpha_mse_gssh: 1.0
#   sigNoise: 0.0
#   flagSWOTData: true
#   rnd1: 0
#   rnd2: 100
#   dwscale: 1
#   UsePriodicBoundary: false
#   InterpFlag: false
#   automatic_optimization: true
#   ckpt_name: modelGP_{epoch:02d}-{val_loss:.2f}
#   norm_obs: l2
#   norm_prior: l2
#   diff_only: true
# datamodule:
#   dim_range:
#     lat:
#       _target_: builtins.slice
#       _args_:
#       - 0
#       - 100
#     lon:
#       _target_: builtins.slice
#       _args_:
#       - 0
#       - 100
#   _target_: oi.dataloading_gp.FourDVarNetDataModule
#   slice_win:
#     lat: 100
#     lon: 100
#     time: 5
#   strides:
#     lat: 100
#     lon: 100
#     time: 1
#   train_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2012-10-01'
#     - '2012-11-20'
#   - _target_: builtins.slice
#     _args_:
#     - '2013-02-07'
#     - '2013-09-10'
#   test_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2013-01-03'
#     - '2013-01-27'
#   val_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2012-11-30'
#     - '2012-12-24'
#   obs_path: ${params.files_cfg.obs_path}
#   obs_var: ${params.files_cfg.obs_var}
#   gt_path: ${params.files_cfg.gt_path}
#   gt_var: ${params.files_cfg.gt_var}
#   dl_kwargs:
#     batch_size: 2
#     num_workers: 2
#   resize_factor: 1
# lit_mod_cls: oi.lit_model_spde.LitModel
# xp_name: oi_gp_spde_learn_params
# seed: 0
#
# /gpfsdswork/projects/rech/yrf/uba22to/4dvarnet-core/hydra_main.py:212: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path='hydra_config', config_name='main')
# get_model:  None
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type                | Params
# -----------------------------------------------------
# 0 | model        | Solver_Grad_4DVarNN | 227 K
# 1 | model_LR     | ModelLR             | 0
# 2 | gradient_img | Gradient_img        | 18
# -----------------------------------------------------
# 227 K     Trainable params
# 23        Non-trainable params
# 227 K     Total params
# 0.908     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]/linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:105: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 80 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Global seed set to 0
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:105: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 80 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/callbacks/lr_monitor.py:112: RuntimeWarning: You are using `LearningRateMonitor` callback with models that have no learning rate schedulers. Please see documentation for `configure_optimizers` method.
#   rank_zero_warn(
# Epoch 0:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=14, v_num=41, loss_step=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 0:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=14, v_num=41, loss_step=1
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 0: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=14, v_num=41, loss_step=1
# Epoch 1:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=7.83, v_num=41, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 1:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=7.83, v_num=41, loss_step
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 1: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=7.83, v_num=41, loss_step
# Epoch 2:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=6.05, v_num=41, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 2:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=6.05, v_num=41, loss_step
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 2: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=6.05, v_num=41, loss_step
# Epoch 3:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=3.37, v_num=41, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 3:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=3.37, v_num=41, loss_step
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.52s/it]
# Epoch 3: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=3.37, v_num=41, loss_step
# Epoch 4:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=2.54, v_num=41, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 4:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=2.54, v_num=41, loss_step
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 4: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=2.54, v_num=41, loss_step
# Epoch 5:  92%|▉| 130/141 [03:17<00:16,  1.50s/it, loss=1.99, v_num=41, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 5:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.99, v_num=41, loss_step
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 5: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.99, v_num=41, loss_step
# Epoch 6:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.81, v_num=41, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 6:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.81, v_num=41, loss_step
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 6: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.81, v_num=41, loss_step
# Epoch 7:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.65, v_num=41, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 7:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.65, v_num=41, loss_step
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 7: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.65, v_num=41, loss_step
# Epoch 8:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.41, v_num=41, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 8:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.41, v_num=41, loss_step
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 8: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.41, v_num=41, loss_step
# Epoch 9:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.37, v_num=41, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 9:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.37, v_num=41, loss_step
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 9: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.37, v_num=41, loss_step
# Epoch 10:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.28, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 10:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.28, v_num=41, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 10: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.28, v_num=41, loss_ste
# Epoch 11:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.26, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 11:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.26, v_num=41, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 11: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.26, v_num=41, loss_ste
# Epoch 12:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.21, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 12:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.21, v_num=41, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 12: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.21, v_num=41, loss_ste
# Epoch 13:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.16, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 13:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.16, v_num=41, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 13: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.16, v_num=41, loss_ste
# Epoch 14:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.14, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 14:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.14, v_num=41, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 14: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.14, v_num=41, loss_ste
# Epoch 15:  92%|▉| 130/141 [03:17<00:16,  1.50s/it, loss=1.12, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 15:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.12, v_num=41, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 15: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.12, v_num=41, loss_ste
# Epoch 16:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.11, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 16:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.11, v_num=41, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 16: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.11, v_num=41, loss_ste
# Epoch 17:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.05, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 17:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.05, v_num=41, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.52s/it]
# Epoch 17: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.05, v_num=41, loss_ste
# Epoch 18:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.08, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 18:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.08, v_num=41, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 18: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.08, v_num=41, loss_ste
# Epoch 19:  92%|▉| 130/141 [03:16<00:16,  1.50s/it, loss=1.05, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 19:  99%|▉| 140/141 [03:24<00:01,  1.45s/it, loss=1.05, v_num=41, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:15<00:01,  1.51s/it]
# Epoch 19: 100%|█| 141/141 [03:32<00:00,  1.50s/it, loss=1.05, v_num=41, loss_ste
# Epoch 20:   0%| | 0/141 [00:00<00:00, 4315.13it/s, loss=1.05, v_num=41, loss_ste... Update Iterations number/learning rate #20: NGrad = 20 -- lr = 0.000100
# Epoch 20:  92%|▉| 130/141 [13:30<01:08,  6.19s/it, loss=1.26, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 20:  99%|▉| 140/141 [14:01<00:05,  5.97s/it, loss=1.26, v_num=41, loss_ste
# Epoch 20: 100%|█| 141/141 [14:31<00:00,  6.14s/it, loss=1.26, v_num=41, loss_ste
# Epoch 20: 100%|█| 141/141 [14:35<00:00,  6.16s/it, loss=1.26, v_num=41, loss_ste
# Epoch 21:  92%|▉| 130/141 [13:30<01:08,  6.19s/it, loss=1.1, v_num=41, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 21:  99%|▉| 140/141 [14:00<00:05,  5.96s/it, loss=1.1, v_num=41, loss_step
# Epoch 21: 100%|█| 141/141 [14:31<00:00,  6.14s/it, loss=1.1, v_num=41, loss_step
# Epoch 21: 100%|█| 141/141 [14:34<00:00,  6.16s/it, loss=1.1, v_num=41, loss_step
# Epoch 22:  92%|▉| 130/141 [13:31<01:08,  6.19s/it, loss=1.09, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 22:  99%|▉| 140/141 [14:01<00:05,  5.97s/it, loss=1.09, v_num=41, loss_ste
# Epoch 22: 100%|█| 141/141 [14:31<00:00,  6.14s/it, loss=1.09, v_num=41, loss_ste
# Epoch 22: 100%|█| 141/141 [14:35<00:00,  6.16s/it, loss=1.09, v_num=41, loss_ste
# Epoch 23:  92%|▉| 130/141 [13:31<01:08,  6.19s/it, loss=1.08, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 23:  99%|▉| 140/141 [14:01<00:05,  5.97s/it, loss=1.08, v_num=41, loss_ste
# Epoch 23: 100%|█| 141/141 [14:32<00:00,  6.14s/it, loss=1.08, v_num=41, loss_ste
# Epoch 23: 100%|█| 141/141 [14:35<00:00,  6.16s/it, loss=1.08, v_num=41, loss_ste
# Epoch 24:  92%|▉| 130/141 [13:31<01:08,  6.19s/it, loss=1.09, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 24:  99%|▉| 140/141 [14:01<00:05,  5.97s/it, loss=1.09, v_num=41, loss_ste
# Epoch 24: 100%|█| 141/141 [14:31<00:00,  6.14s/it, loss=1.09, v_num=41, loss_ste
# Epoch 24: 100%|█| 141/141 [14:34<00:00,  6.16s/it, loss=1.09, v_num=41, loss_ste
# Epoch 25:  92%|▉| 130/141 [13:30<01:08,  6.19s/it, loss=1.03, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 25:  99%|▉| 140/141 [14:01<00:05,  5.97s/it, loss=1.03, v_num=41, loss_ste
# Epoch 25: 100%|█| 141/141 [14:31<00:00,  6.14s/it, loss=1.03, v_num=41, loss_ste
# Epoch 25: 100%|█| 141/141 [14:34<00:00,  6.16s/it, loss=1.03, v_num=41, loss_ste
# Epoch 26:  92%|▉| 130/141 [13:30<01:08,  6.19s/it, loss=1.02, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 26:  99%|▉| 140/141 [14:00<00:05,  5.96s/it, loss=1.02, v_num=41, loss_ste
# Epoch 26: 100%|█| 141/141 [14:31<00:00,  6.14s/it, loss=1.02, v_num=41, loss_ste
# Epoch 26: 100%|█| 141/141 [14:34<00:00,  6.16s/it, loss=1.02, v_num=41, loss_ste
# Epoch 27:  92%|▉| 130/141 [13:30<01:08,  6.19s/it, loss=1.02, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 27:  99%|▉| 140/141 [14:00<00:05,  5.96s/it, loss=1.02, v_num=41, loss_ste
# Epoch 27: 100%|█| 141/141 [14:31<00:00,  6.14s/it, loss=1.02, v_num=41, loss_ste
# Epoch 27: 100%|█| 141/141 [14:34<00:00,  6.16s/it, loss=1.02, v_num=41, loss_ste
# Epoch 28:  92%|▉| 130/141 [13:30<01:08,  6.19s/it, loss=1.01, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 28:  99%|▉| 140/141 [14:01<00:05,  5.97s/it, loss=1.01, v_num=41, loss_ste
# Epoch 28: 100%|█| 141/141 [14:31<00:00,  6.14s/it, loss=1.01, v_num=41, loss_ste
# Epoch 28: 100%|█| 141/141 [14:34<00:00,  6.16s/it, loss=1.01, v_num=41, loss_ste
# Epoch 29:  92%|▉| 130/141 [13:31<01:08,  6.19s/it, loss=1.01, v_num=41, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 29:  99%|▉| 140/141 [14:01<00:05,  5.97s/it, loss=1.01, v_num=41, loss_ste
# Epoch 29: 100%|█| 141/141 [14:31<00:00,  6.14s/it, loss=1.01, v_num=41, loss_ste
# Epoch 29: 100%|█| 141/141 [14:34<00:00,  6.16s/it, loss=1.01, v_num=41, loss_ste
# Epoch 29: 100%|█| 141/141 [14:34<00:00,  6.16s/it, loss=1.01, v_num=41, loss_ste
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:678: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:105: UserWarning: The dataloader, test dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 80 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 100%|██████████████████████████████████| 11/11 [01:03<00:00,  5.14s/it]mse_pred =  0.07176737
# grad_mse_pred =  0.008515636827733293
# /gpfsdswork/projects/rech/yrf/uba22to/4dvarnet-core/spectral.py:55: RuntimeWarning: invalid value encountered in true_divide
#   pf_ = (pf_/rapsd2dv1(img2,res,hanning)[1])
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_loss': 1.1771183013916016,
#  'test_mse': 0.07210729271173477,
#  'test_mseG': 0.4983982741832733}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 11/11 [01:08<00:00,  6.19s/it]

# %% [markdown]
# # 3. Retrieve and import the results

# %%
import glob
from datetime import datetime
import numpy as np

dirs = glob.glob("/gpfswork/rech/yrf/uba22to/4dvarnet-core/dashboard/oi_gp_spde_learn_params/lightning_logs/*")
file = max(dirs, key=os.path.getctime) + "/maps.nc"
print(file)

# import 4dvarNet reconstruction
data_4dvarnet = xr.open_dataset(file).isel(daw=2)
#time = [ np.datetime_as_string(date, unit='D') for date in data_4dvarnet.time.values ]
time = data_4dvarnet.Time.values

# import OI baseline
file = "/gpfswork/rech/yrf/uba22to/4dvarnet-core/oi/data/SPDE_diffusion_dataset.nc"
data_baseline = xr.open_dataset(file)
data_baseline['time'] = pd.date_range(start="2012-10-01", periods=data_baseline.sizes['time'], freq='D')
data_baseline = data_baseline.sel(time=slice(time[0],time[-1]))

# rename variables
data_baseline = data_baseline.update({
                     'gt':(('time','lat','lon'),data_4dvarnet.gt.values),
                     'obs_inp':(('time','lat','lon'),data_4dvarnet.obs.values),
                     'pred':(('time','lat','lon'),data_baseline.OI.values)})
data_4dvarnet = data_4dvarnet.update({
                     'obs_inp':(('time','lat','lon'),
                                np.where(data_4dvarnet.obs.values==np.median(data_4dvarnet.obs.values),np.nan,data_4dvarnet.obs.values))})
# Out:
# /gpfswork/rech/yrf/uba22to/4dvarnet-core/dashboard/oi_gp_spde_learn_params/lightning_logs/version_42/maps.nc

# %%
plt.figure(figsize=(30,10))
plt.subplot(131)
data_baseline.H11.plot()
plt.subplot(132)
data_baseline.H12.plot()
plt.subplot(133)
data_baseline.H22.plot()
plt.figure(figsize=(30,10))
plt.subplot(131)
data_4dvarnet.H11.plot()
plt.subplot(132)
data_4dvarnet.H12.plot()
plt.subplot(133)
data_4dvarnet.H22.plot()
plt.show()
plt.close()

# %% [markdown]
# ## 2. Compute RMSE-based scores

# %%
rmse_t_pred_baseline, rmse_xy_pred_baseline, nrmse_pred_baseline, nrmse_std_pred_baseline = rmse_based_scores(data_baseline,'pred')
rmse_t_pred_4dvarnet, rmse_xy_pred_4dvarnet, nrmse_pred_4dvarnet, nrmse_std_pred_4dvarnet = rmse_based_scores(data_4dvarnet,'pred')

# %% [markdown]
# ## 3. Compute spectral scores

# %%
# %matplotlib inline  

ds_psd_pred_baseline, lambda_x_pred_baseline, lambda_t_pred_baseline = psd_based_scores(data_baseline,'pred',dx=1,dt=1)
ds_psd_pred_4dvarnet, lambda_x_pred_4dvarnet, lambda_t_pred_4dvarnet = psd_based_scores(data_4dvarnet,'pred',dx=1,dt=1)

psd_concat = xr.concat((ds_psd_pred_4dvarnet, ds_psd_pred_baseline), dim='experiment')
psd_concat['experiment'] = ["4dvarnet","baseline"]
plot_psd_score(psd_concat,dx=1,dt=1)
# Out:
# [###########                             ] | 28% Completed |  0.1s
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/xrft/xrft.py:49: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# [########################################] | 100% Completed |  0.4s
# [                                        ] | 0% Completed |  0.0s
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/xrft/xrft.py:49: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# [########################################] | 100% Completed |  0.4s
# [##########                              ] | 25% Completed |  0.1s
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/xrft/xrft.py:49: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# [########################################] | 100% Completed |  0.4s
# [#########                               ] | 23% Completed |  0.1s
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/xrft/xrft.py:49: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# [########################################] | 100% Completed |  0.4s

# %% [markdown]
# ## 4. Export RMSE and spectral scores

# %%
tab_score = pd.DataFrame(dict(name=['4dVarnet',"baseline"],
                  mu_RMSE=[nrmse_pred_4dvarnet,nrmse_pred_baseline],
                  std_RMSE=[nrmse_std_pred_4dvarnet,nrmse_std_pred_baseline],
                  lambda_x_degree=[lambda_x_pred_4dvarnet,lambda_x_pred_baseline],
                  lambda_t_days=[lambda_t_pred_4dvarnet,lambda_t_pred_baseline],
                  Notes = ['4dvarnet','baseline']))
tab_score
# Out:
#        name  mu_RMSE  std_RMSE  lambda_x_degree  lambda_t_days     Notes
# 0  4dVarnet     0.22      0.04            38.68          19.14  4dvarnet
# 1  baseline     0.31      0.04            26.61          17.21  baseline

# %% [markdown]
# ## 5. Display nRMSE time series on the test period

# %%
TS(list_data=[data_baseline.gt.values,data_baseline.obs_inp.values,
              data_baseline.pred.values, data_4dvarnet.pred.values],
   labels_data=np.array(['GT','Obs', 'OI (baseline)', '4DVarNet']),
   colors=np.array(['k','','red','seagreen']),
   symbols=np.array(['k','','o','o']),
   lstyle=np.array(['solid','','solid','solid']),lwidth = np.array([2,2,2,2]),
   dt=1,
   gradient=False)

# %% [markdown]
# ## 6. Display raw and gradient fields

# %%
itime = 20
plot_maps(data_baseline.gt[itime].values,data_baseline.obs_inp[itime].values,
          [data_baseline.pred[itime].values,data_4dvarnet.pred[itime].values],[],
          data_baseline.lon,data_baseline.lat,new_method='4DVarNet',grad=False, 
          orthographic=True,cartopy=False,figsize=(10,15))

# %%
plot_maps(data_baseline.gt[itime].values,data_baseline.obs_inp[itime].values,
          [data_baseline.pred[itime].values,data_4dvarnet.pred[itime].values],[],
          data_baseline.lon,data_baseline.lat,new_method='4DVarNet',grad=True, 
          orthographic=True,cartopy=False,figsize=(10,15))
