# %% [markdown]
# # 4DVarNet-OI Evaluation Notebook (OSSE)

# %% [markdown]
# ## 1. Import tools and change directory

# %%
from utils_OSSE import *
import pandas as pd
import os

# %%
os.chdir("/gpfswork/rech/yrf/uba22to/4dvarnet-core")
print(os.getcwd())
# Out:
# /gpfsdswork/projects/rech/yrf/uba22to/4dvarnet-core

# %% [markdown]
# ## 2. Run the code

# %%
# !python hydra_main.py xp=oi_osse file_paths=dc_osse entrypoint=run entrypoint.max_epochs=30 datamodule.gt_path=/gpfsstore/rech/yrf/commun/NATL60/NATL/oi/ssh_NATL60_swot_4nadir.nc datamodule.gt_var=ssh_obs
# Out:
# /gpfsdswork/projects/rech/yrf/uba22to/4dvarnet-core/hydra_main.py:194: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path='hydra_config', config_name='main')
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/upgrades/1.1_to_1.2/changes_to_job_working_dir for more information.
#   ret = run_job(
# Global seed set to 0
# file_paths:
#   oi_path: /gpfsstore/rech/yrf/commun/NATL60/NATL/oi/ssh_NATL60_swot_4nadir.nc
#   obs_mask_path: /gpfsstore/rech/yrf/commun/NATL60/NATL/data_new/dataset_nadir_0d_swot.nc
#   gt_path: /gpfsstore/rech/yrf/commun/NATL60/NATL/ref/NATL60-CJM165_NATL_ssh_y2013.1y.nc
#   sst_path: /gpfsstore/rech/yrf/commun/NATL60/NATL/ref/NATL60-CJM165_NATL_sst_y2013.1y.nc
# entrypoint:
#   _target_: hydra_main.FourDVarNetHydraRunner.run
#   max_epochs: 30
#   progress_bar_refresh_rate: 5
# params:
#   files_cfg:
#     obs_mask_path: ${file_paths.obs_mask_path}
#     obs_mask_var: ssh_obs
#     gt_path: ${file_paths.gt_path}
#     gt_var: ssh
#   iter_update:
#   - 0
#   - 20
#   - 40
#   - 60
#   - 100
#   - 150
#   - 800
#   nb_grad_update:
#   - 5
#   - 5
#   - 10
#   - 10
#   - 20
#   - 30
#   - 50
#   - 50
#   - 50
#   lr_update:
#   - 0.001
#   - 0.0001
#   - 0.001
#   - 0.0001
#   - 0.0001
#   - 1.0e-05
#   - 1.0e-05
#   - 1.0e-06
#   - 1.0e-07
#   k_batch: 1
#   n_grad: 5
#   dT: 29
#   dx: 1
#   W: 100
#   resize_factor: 4
#   resolution: 1/5
#   shapeData:
#   - 29
#   - 200
#   - 200
#   dW: 3
#   dW2: 1
#   sS: 4
#   nbBlocks: 1
#   Nbpatches: 1
#   stochastic: false
#   size_ensemble: 1
#   animate: true
#   supervised: true
#   DimAE: 25
#   dim_grad_solver: 70
#   dropout: 0.25
#   dropout_phi_r: 0.0
#   alpha_proj: 0.5
#   alpha_sr: 0.5
#   alpha_lr: 0.5
#   alpha_mse_ssh: 10.0
#   alpha_mse_gssh: 1.0
#   sigNoise: 0.0
#   flagSWOTData: true
#   rnd1: 0
#   rnd2: 100
#   dwscale: 1
#   UsePriodicBoundary: false
#   InterpFlag: false
#   automatic_optimization: true
#   ckpt_name: modelOI_{epoch:02d}-{val_loss:.2f}
#   norm_obs: l2
#   norm_prior: l2
# datamodule:
#   dim_range:
#     lat:
#       _target_: builtins.slice
#       _args_:
#       - 33.0
#       - 43.0
#     lon:
#       _target_: builtins.slice
#       _args_:
#       - -65.0
#       - -55.0
#   _target_: oi.dataloading_osse.FourDVarNetDataModule
#   slice_win:
#     lat: 200
#     lon: 200
#     time: 29
#   strides:
#     lat: 200
#     lon: 200
#     time: 1
#   train_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2012-10-01'
#     - '2012-11-20'
#   - _target_: builtins.slice
#     _args_:
#     - '2013-02-07'
#     - '2013-09-10'
#   test_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2013-01-03'
#     - '2013-02-27'
#   val_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2012-11-30'
#     - '2013-01-30'
#   obs_mask_path: ${params.files_cfg.obs_mask_path}
#   obs_mask_var: ${params.files_cfg.obs_mask_var}
#   gt_path: /gpfsstore/rech/yrf/commun/NATL60/NATL/oi/ssh_NATL60_swot_4nadir.nc
#   gt_var: ssh_obs
#   resize_factor: ${params.resize_factor}
#   resolution: ${params.resolution}
#   dl_kwargs:
#     batch_size: 2
#     num_workers: 2
# lit_mod_cls: oi.lit_model.LitModel
# xp_name: oi_osse
# seed: 0
#
# Using current oi.dataloading_osse
# Using current oi.metrics
# [2022-05-13 09:55:28,588][cartopy_userconfig][INFO] - Setting cartopy.config["pre_existing_data_dir"] to /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/share/cartopy. Don't worry, this is probably intended behaviour to avoid failing downloads of geological data behind a firewall.
# file_paths:
#   oi_path: /gpfsstore/rech/yrf/commun/NATL60/NATL/oi/ssh_NATL60_swot_4nadir.nc
#   obs_mask_path: /gpfsstore/rech/yrf/commun/NATL60/NATL/data_new/dataset_nadir_0d_swot.nc
#   gt_path: /gpfsstore/rech/yrf/commun/NATL60/NATL/ref/NATL60-CJM165_NATL_ssh_y2013.1y.nc
#   sst_path: /gpfsstore/rech/yrf/commun/NATL60/NATL/ref/NATL60-CJM165_NATL_sst_y2013.1y.nc
# entrypoint:
#   _target_: hydra_main.FourDVarNetHydraRunner.run
#   max_epochs: 30
#   progress_bar_refresh_rate: 5
# params:
#   files_cfg:
#     obs_mask_path: ${file_paths.obs_mask_path}
#     obs_mask_var: ssh_obs
#     gt_path: ${file_paths.gt_path}
#     gt_var: ssh
#   iter_update:
#   - 0
#   - 20
#   - 40
#   - 60
#   - 100
#   - 150
#   - 800
#   nb_grad_update:
#   - 5
#   - 5
#   - 10
#   - 10
#   - 20
#   - 30
#   - 50
#   - 50
#   - 50
#   lr_update:
#   - 0.001
#   - 0.0001
#   - 0.001
#   - 0.0001
#   - 0.0001
#   - 1.0e-05
#   - 1.0e-05
#   - 1.0e-06
#   - 1.0e-07
#   k_batch: 1
#   n_grad: 5
#   dT: 29
#   dx: 1
#   W: 100
#   resize_factor: 4
#   resolution: 1/5
#   shapeData:
#   - 29
#   - 200
#   - 200
#   dW: 3
#   dW2: 1
#   sS: 4
#   nbBlocks: 1
#   Nbpatches: 1
#   stochastic: false
#   size_ensemble: 1
#   animate: true
#   supervised: true
#   DimAE: 25
#   dim_grad_solver: 70
#   dropout: 0.25
#   dropout_phi_r: 0.0
#   alpha_proj: 0.5
#   alpha_sr: 0.5
#   alpha_lr: 0.5
#   alpha_mse_ssh: 10.0
#   alpha_mse_gssh: 1.0
#   sigNoise: 0.0
#   flagSWOTData: true
#   rnd1: 0
#   rnd2: 100
#   dwscale: 1
#   UsePriodicBoundary: false
#   InterpFlag: false
#   automatic_optimization: true
#   ckpt_name: modelOI_{epoch:02d}-{val_loss:.2f}
#   norm_obs: l2
#   norm_prior: l2
# datamodule:
#   dim_range:
#     lat:
#       _target_: builtins.slice
#       _args_:
#       - 33.0
#       - 43.0
#     lon:
#       _target_: builtins.slice
#       _args_:
#       - -65.0
#       - -55.0
#   _target_: oi.dataloading_osse.FourDVarNetDataModule
#   slice_win:
#     lat: 50
#     lon: 50
#     time: 29
#   strides:
#     lat: 50
#     lon: 50
#     time: 1
#   train_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2012-10-01'
#     - '2012-11-20'
#   - _target_: builtins.slice
#     _args_:
#     - '2013-02-07'
#     - '2013-09-10'
#   test_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2013-01-03'
#     - '2013-02-27'
#   val_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2012-11-30'
#     - '2013-01-30'
#   obs_mask_path: ${params.files_cfg.obs_mask_path}
#   obs_mask_var: ${params.files_cfg.obs_mask_var}
#   gt_path: /gpfsstore/rech/yrf/commun/NATL60/NATL/oi/ssh_NATL60_swot_4nadir.nc
#   gt_var: ssh_obs
#   resize_factor: ${params.resize_factor}
#   resolution: ${params.resolution}
#   dl_kwargs:
#     batch_size: 2
#     num_workers: 2
# lit_mod_cls: oi.lit_model.LitModel
# xp_name: oi_osse
# seed: 0
#
# /gpfsstore/rech/yrf/commun/NATL60/NATL/oi/ssh_NATL60_swot_4nadir.nc
# /gpfsstore/rech/yrf/commun/NATL60/NATL/data_new/dataset_nadir_0d_swot.nc
# /gpfsstore/rech/yrf/commun/NATL60/NATL/oi/ssh_NATL60_swot_4nadir.nc
# /gpfsstore/rech/yrf/commun/NATL60/NATL/data_new/dataset_nadir_0d_swot.nc
# /gpfsstore/rech/yrf/commun/NATL60/NATL/oi/ssh_NATL60_swot_4nadir.nc
# /gpfsstore/rech/yrf/commun/NATL60/NATL/data_new/dataset_nadir_0d_swot.nc
# /gpfsstore/rech/yrf/commun/NATL60/NATL/oi/ssh_NATL60_swot_4nadir.nc
# /gpfsstore/rech/yrf/commun/NATL60/NATL/data_new/dataset_nadir_0d_swot.nc
# 0
# /gpfsdswork/projects/rech/yrf/uba22to/4dvarnet-core/hydra_main.py:194: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path='hydra_config', config_name='main')
# get_model:  None
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type                | Params
# -----------------------------------------------------
# 0 | model        | Solver_Grad_4DVarNN | 383 K
# 1 | model_LR     | ModelLR             | 0
# 2 | gradient_img | Gradient_img        | 18
# -----------------------------------------------------
# 383 K     Trainable params
# 47        Non-trainable params
# 383 K     Total params
# 1.534     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]/linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:105: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 80 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Global seed set to 0
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:105: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 80 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/callbacks/lr_monitor.py:112: RuntimeWarning: You are using `LearningRateMonitor` callback with models that have no learning rate schedulers. Please see documentation for `configure_optimizers` method.
#   rank_zero_warn(
# Epoch 0:  89%|▉| 110/123 [00:30<00:03,  3.63it/s, loss=0.558, v_num=1743829, los
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 0:  93%|▉| 115/123 [00:31<00:02,  3.71it/s, loss=0.558, v_num=1743829, los
# Epoch 0:  98%|▉| 120/123 [00:31<00:00,  3.81it/s, loss=0.558, v_num=1743829, los
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.78it/s]
# Epoch 0: 100%|█| 123/123 [00:32<00:00,  3.82it/s, loss=0.543, v_num=1743829, los
# Epoch 1:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.409, v_num=1743829, los
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 1:  93%|▉| 115/123 [00:31<00:02,  3.73it/s, loss=0.409, v_num=1743829, los
# Epoch 1:  98%|▉| 120/123 [00:31<00:00,  3.83it/s, loss=0.409, v_num=1743829, los
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.78it/s]
# Epoch 1: 100%|█| 123/123 [00:32<00:00,  3.84it/s, loss=0.411, v_num=1743829, los
# Epoch 2:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.336, v_num=1743829, los
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 2:  93%|▉| 115/123 [00:31<00:02,  3.73it/s, loss=0.336, v_num=1743829, los
# Epoch 2:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.336, v_num=1743829, los
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.75it/s]
# Epoch 2: 100%|█| 123/123 [00:32<00:00,  3.84it/s, loss=0.332, v_num=1743829, los
# Epoch 3:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.277, v_num=1743829, los
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 3:  93%|▉| 115/123 [00:31<00:02,  3.73it/s, loss=0.277, v_num=1743829, los
# Epoch 3:  98%|▉| 120/123 [00:31<00:00,  3.83it/s, loss=0.277, v_num=1743829, los
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.79it/s]
# Epoch 3: 100%|█| 123/123 [00:32<00:00,  3.84it/s, loss=0.276, v_num=1743829, los
# Epoch 4:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.244, v_num=1743829, los
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 4:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.244, v_num=1743829, los
# Epoch 4:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.244, v_num=1743829, los
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.82it/s]
# Epoch 4: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.242, v_num=1743829, los
# Epoch 5:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.194, v_num=1743829, los
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 5:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.194, v_num=1743829, los
# Epoch 5:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.194, v_num=1743829, los
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.77it/s]
# Epoch 5: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.199, v_num=1743829, los
# Epoch 6:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.194, v_num=1743829, los
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 6:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.194, v_num=1743829, los
# Epoch 6:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.194, v_num=1743829, los
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.75it/s]
# Epoch 6: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.195, v_num=1743829, los
# Epoch 7:  89%|▉| 110/123 [00:30<00:03,  3.64it/s, loss=0.19, v_num=1743829, loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 7:  93%|▉| 115/123 [00:31<00:02,  3.72it/s, loss=0.19, v_num=1743829, loss
# Epoch 7:  98%|▉| 120/123 [00:31<00:00,  3.83it/s, loss=0.19, v_num=1743829, loss
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.73it/s]
# Epoch 7: 100%|█| 123/123 [00:32<00:00,  3.83it/s, loss=0.186, v_num=1743829, los
# Epoch 8:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.175, v_num=1743829, los
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 8:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.175, v_num=1743829, los
# Epoch 8:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.175, v_num=1743829, los
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.79it/s]
# Epoch 8: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.173, v_num=1743829, los
# Epoch 9:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.177, v_num=1743829, los
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 9:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.177, v_num=1743829, los
# Epoch 9:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.177, v_num=1743829, los
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.79it/s]
# Epoch 9: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.177, v_num=1743829, los
# Epoch 10:  89%|▉| 110/123 [00:30<00:03,  3.66it/s, loss=0.181, v_num=1743829, lo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 10:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.181, v_num=1743829, lo
# Epoch 10:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.181, v_num=1743829, lo
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.80it/s]
# Epoch 10: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.18, v_num=1743829, los
# Epoch 11:  89%|▉| 110/123 [00:30<00:03,  3.66it/s, loss=0.153, v_num=1743829, lo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 11:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.153, v_num=1743829, lo
# Epoch 11:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.153, v_num=1743829, lo
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.80it/s]
# Epoch 11: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.151, v_num=1743829, lo
# Epoch 12:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.149, v_num=1743829, lo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 12:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.149, v_num=1743829, lo
# Epoch 12:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.149, v_num=1743829, lo
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.78it/s]
# Epoch 12: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.146, v_num=1743829, lo
# Epoch 13:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.156, v_num=1743829, lo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 13:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.156, v_num=1743829, lo
# Epoch 13:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.156, v_num=1743829, lo
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.78it/s]
# Epoch 13: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.158, v_num=1743829, lo
# Epoch 14:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.139, v_num=1743829, lo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 14:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.139, v_num=1743829, lo
# Epoch 14:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.139, v_num=1743829, lo
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.82it/s]
# Epoch 14: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.14, v_num=1743829, los
# Epoch 15:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.115, v_num=1743829, lo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 15:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.115, v_num=1743829, lo
# Epoch 15:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.115, v_num=1743829, lo
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.79it/s]
# Epoch 15: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.116, v_num=1743829, lo
# Epoch 16:  89%|▉| 110/123 [00:30<00:03,  3.66it/s, loss=0.124, v_num=1743829, lo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 16:  93%|▉| 115/123 [00:30<00:02,  3.74it/s, loss=0.124, v_num=1743829, lo
# Epoch 16:  98%|▉| 120/123 [00:31<00:00,  3.85it/s, loss=0.124, v_num=1743829, lo
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.80it/s]
# Epoch 16: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.123, v_num=1743829, lo
# Epoch 17:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.119, v_num=1743829, lo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 17:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.119, v_num=1743829, lo
# Epoch 17:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.119, v_num=1743829, lo
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.80it/s]
# Epoch 17: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.122, v_num=1743829, lo
# Epoch 18:  89%|▉| 110/123 [00:30<00:03,  3.66it/s, loss=0.143, v_num=1743829, lo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 18:  93%|▉| 115/123 [00:30<00:02,  3.74it/s, loss=0.143, v_num=1743829, lo
# Epoch 18:  98%|▉| 120/123 [00:31<00:00,  3.85it/s, loss=0.143, v_num=1743829, lo
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.82it/s]
# Epoch 18: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.139, v_num=1743829, lo
# Epoch 19:  89%|▉| 110/123 [00:30<00:03,  3.66it/s, loss=0.118, v_num=1743829, lo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 19:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.118, v_num=1743829, lo
# Epoch 19:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.118, v_num=1743829, lo
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.83it/s]
# Epoch 19: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.117, v_num=1743829, lo
# Epoch 20:   0%| | 0/123 [00:00<00:00, 3721.65it/s, loss=0.117, v_num=1743829, lo... Update Iterations number/learning rate #20: NGrad = 5 -- lr = 0.000100
# Epoch 20:  89%|▉| 110/123 [00:30<00:03,  3.66it/s, loss=0.0979, v_num=1743829, l
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 20:  93%|▉| 115/123 [00:30<00:02,  3.74it/s, loss=0.0979, v_num=1743829, l
# Epoch 20:  98%|▉| 120/123 [00:31<00:00,  3.85it/s, loss=0.0979, v_num=1743829, l
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.79it/s]
# Epoch 20: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.0983, v_num=1743829, l
# Epoch 21:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.0956, v_num=1743829, l
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 21:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.0956, v_num=1743829, l
# Epoch 21:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.0956, v_num=1743829, l
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.83it/s]
# Epoch 21: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.0956, v_num=1743829, l
# Epoch 22:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.103, v_num=1743829, lo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 22:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.103, v_num=1743829, lo
# Epoch 22:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.103, v_num=1743829, lo
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.81it/s]
# Epoch 22: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.102, v_num=1743829, lo
# Epoch 23:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.0942, v_num=1743829, l
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 23:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.0942, v_num=1743829, l
# Epoch 23:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.0942, v_num=1743829, l
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.80it/s]
# Epoch 23: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.0952, v_num=1743829, l
# Epoch 24:  89%|▉| 110/123 [00:30<00:03,  3.65it/s, loss=0.0954, v_num=1743829, l
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 24:  93%|▉| 115/123 [00:31<00:02,  3.73it/s, loss=0.0954, v_num=1743829, l
# Epoch 24:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.0954, v_num=1743829, l
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.77it/s]
# Epoch 24: 100%|█| 123/123 [00:32<00:00,  3.84it/s, loss=0.0949, v_num=1743829, l
# Epoch 25:  89%|▉| 110/123 [00:30<00:03,  3.66it/s, loss=0.096, v_num=1743829, lo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 25:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.096, v_num=1743829, lo
# Epoch 25:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.096, v_num=1743829, lo
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.83it/s]
# Epoch 25: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.0956, v_num=1743829, l
# Epoch 26:  89%|▉| 110/123 [00:30<00:03,  3.66it/s, loss=0.0951, v_num=1743829, l
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 26:  93%|▉| 115/123 [00:30<00:02,  3.74it/s, loss=0.0951, v_num=1743829, l
# Epoch 26:  98%|▉| 120/123 [00:31<00:00,  3.85it/s, loss=0.0951, v_num=1743829, l
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.83it/s]
# Epoch 26: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.0961, v_num=1743829, l
# Epoch 27:  89%|▉| 110/123 [00:30<00:03,  3.66it/s, loss=0.0949, v_num=1743829, l
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 27:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.0949, v_num=1743829, l
# Epoch 27:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.0949, v_num=1743829, l
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.83it/s]
# Epoch 27: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.0952, v_num=1743829, l
# Epoch 28:  89%|▉| 110/123 [00:30<00:03,  3.66it/s, loss=0.0885, v_num=1743829, l
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 28:  93%|▉| 115/123 [00:31<00:02,  3.74it/s, loss=0.0885, v_num=1743829, l
# Epoch 28:  98%|▉| 120/123 [00:31<00:00,  3.84it/s, loss=0.0885, v_num=1743829, l
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.81it/s]
# Epoch 28: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.0874, v_num=1743829, l
# Epoch 29:  89%|▉| 110/123 [00:30<00:03,  3.66it/s, loss=0.0894, v_num=1743829, l
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Epoch 29:  93%|▉| 115/123 [00:30<00:02,  3.74it/s, loss=0.0894, v_num=1743829, l
# Epoch 29:  98%|▉| 120/123 [00:31<00:00,  3.85it/s, loss=0.0894, v_num=1743829, l
# Validating:  88%|███████████████████████████▎   | 15/17 [00:01<00:00,  9.78it/s]
# Epoch 29: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.09, v_num=1743829, los
# Epoch 29: 100%|█| 123/123 [00:32<00:00,  3.85it/s, loss=0.09, v_num=1743829, los
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:678: LightningDeprecationWarning: `trainer.test(test_dataloaders)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.test(dataloaders)` instead.
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:105: UserWarning: The dataloader, test dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 80 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 100%|██████████████████████████████████| 14/14 [00:01<00:00,  8.69it/s]mse_pred =  0.000644968
# grad_mse_pred =  0.0001160603034344914
# /gpfsdswork/projects/rech/yrf/uba22to/4dvarnet-core/spectral.py:55: RuntimeWarning: invalid value encountered in true_divide
#   pf_ = (pf_/rapsd2dv1(img2,res,hanning)[1])
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_loss': 0.060059886425733566,
#  'test_mse': 0.031214246526360512,
#  'test_mseG': 0.02091960422694683}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 14/14 [00:05<00:00,  2.64it/s]

# %% [markdown]
# # 3. Retrieve and import the results

# %%
import glob
from datetime import datetime
import numpy as np

dirs = glob.glob("/gpfswork/rech/yrf/uba22to/4dvarnet-core/dashboard/oi_osse/lightning_logs/*")
file = max(dirs, key=os.path.getctime) + "/maps.nc"
print(file)

# import 4dvarNet reconstruction
data_4dvarnet = xr.open_dataset(file)
#time = [ np.datetime_as_string(date, unit='D') for date in data_4dvarnet.time.values ]
time = data_4dvarnet.Time.values

# import OI baseline
file = "/gpfsstore/rech/yrf/commun/NATL60/NATL/oi/ssh_NATL60_swot_4nadir.nc"
data_baseline = xr.open_dataset(file)
data_baseline = data_baseline.sel(time=slice(time[0],time[-1]),
                                  lat=slice(33,43),
                                  lon=slice(-65.0,-55))
# coarsen OI with factor 4
data_baseline = data_baseline.coarsen(lon=4).mean(skipna=True).coarsen(lat=4).mean(skipna=True)

# import GT baseline
file = "/gpfsstore/rech/yrf/commun/NATL60/NATL/ref/NATL60-CJM165_NATL_ssh_y2013.1y.nc"
data_gt = xr.open_dataset(file)
data_gt.time.attrs["units"] = "seconds since 2012-10-01"
data_gt = xr.decode_cf(data_gt)
data_gt = data_gt.sel(time=slice(time[0],time[-1]),
                                  lat=slice(33,43),
                                  lon=slice(-65.0,-55))
# coarsen GT with factor 4
data_gt= data_gt.coarsen(lon=4).mean(skipna=True).coarsen(lat=4).mean(skipna=True)


# rename variables
data_baseline = data_baseline.update({
                     'gt':(('time','lat','lon'),data_gt.ssh.values),
                     'obs_inp':(('time','lat','lon'),data_4dvarnet.OBS.values),
                     'pred':(('time','lat','lon'),data_baseline.ssh_obs.values)})
data_4dvarnet = data_4dvarnet.update({
                     'gt':(('time','lat','lon'),data_gt.ssh.values),
                     'obs_inp':(('time','lat','lon'),data_4dvarnet.OBS.values),
                     'pred':(('time','lat','lon'),data_4dvarnet['4DVarNet'].values)})
# Out:
# /gpfswork/rech/yrf/uba22to/4dvarnet-core/dashboard/oi_osse/lightning_logs/version_1743830/maps.nc

# %% [markdown]
# ## 2. Compute RMSE-based scores

# %%
rmse_t_pred_baseline, rmse_xy_pred_baseline, nrmse_pred_baseline, nrmse_std_pred_baseline = rmse_based_scores(data_baseline,'pred')
rmse_t_pred_4dvarnet, rmse_xy_pred_4dvarnet, nrmse_pred_4dvarnet, nrmse_std_pred_4dvarnet = rmse_based_scores(data_4dvarnet,'pred')

# %% [markdown]
# ## 3. Compute spectral scores

# %%
# %matplotlib inline  

ds_psd_pred_baseline, lambda_x_pred_baseline, lambda_t_pred_baseline = psd_based_scores(data_baseline,'pred')
ds_psd_pred_4dvarnet, lambda_x_pred_4dvarnet, lambda_t_pred_4dvarnet = psd_based_scores(data_4dvarnet,'pred')

psd_concat = xr.concat((ds_psd_pred_4dvarnet, ds_psd_pred_baseline), dim='experiment')
psd_concat['experiment'] = ["4dvarnet","baseline"]
plot_psd_score(psd_concat)
# Out:
# [######################                  ] | 56% Completed |  0.1s
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/xrft/xrft.py:49: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# [########################################] | 100% Completed |  0.2s
# [#######################                 ] | 58% Completed |  0.1s
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/xrft/xrft.py:49: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# [########################################] | 100% Completed |  0.2s
# [#######################                 ] | 57% Completed |  0.1s
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/xrft/xrft.py:49: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# [########################################] | 100% Completed |  0.2s
# [######################                  ] | 56% Completed |  0.1s
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/xrft/xrft.py:49: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# [########################################] | 100% Completed |  0.2s

# %% [markdown]
# ## 4. Export RMSE and spectral scores

# %%
tab_score = pd.DataFrame(dict(name=['4dVarnet',"baseline"],
                  mu_RMSE=[nrmse_pred_4dvarnet,nrmse_pred_baseline],
                  std_RMSE=[nrmse_std_pred_4dvarnet,nrmse_std_pred_baseline],
                  lambda_x_degree=[lambda_x_pred_4dvarnet,lambda_x_pred_baseline],
                  lambda_t_days=[lambda_t_pred_4dvarnet,lambda_t_pred_baseline],
                  Notes = ['4dvarnet','baseline']))
tab_score
# Out:
#        name  mu_RMSE  std_RMSE  lambda_x_degree  lambda_t_days     Notes
# 0  4dVarnet     0.90      0.02             1.48          11.01  4dvarnet
# 1  baseline     0.91      0.02             1.43          11.30  baseline

# %% [markdown]
# ## 5. Display nRMSE time series on the test period

# %%
TS(list_data=[data_baseline.gt.values,data_baseline.obs_inp.values,
              data_baseline.pred.values, data_4dvarnet.pred.values],
   labels_data=np.array(['GT','Obs', 'OI (baseline)', '4DVarNet']),
   colors=np.array(['k','','red','seagreen']),
   symbols=np.array(['k','','o','o']),
   lstyle=np.array(['solid','','solid','solid']),lwidth = np.array([2,2,2,2]),
   lday=time,
   gradient=False)

# %% [markdown]
# ## 6. Display raw and gradient fields

# %%
itime = 20
plot_maps(data_baseline.gt[itime].values,data_baseline.obs_inp[itime].values,
          [data_baseline.pred[itime].values,data_4dvarnet.pred[itime].values],[],
          data_baseline.lon,data_baseline.lat,new_method='4DVarNet',grad=False, 
          orthographic=True,cartopy=True,figsize=(10,15))
# Out:
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/mpl/gridliner.py:336: UserWarning: The .xlabels_bottom attribute is deprecated. Please use .bottom_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_bottom attribute is deprecated. Please '
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/mpl/gridliner.py:360: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/crs.py:228: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/crs.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/crs.py:347: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/crs.py:239: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/crs.py:239: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/crs.py:385: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/crs.py:385: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)

# %%
plot_maps(data_baseline.gt[itime].values,data_baseline.obs_inp[itime].values,
          [data_baseline.pred[itime].values,data_4dvarnet.pred[itime].values],[],
          data_baseline.lon,data_baseline.lat,new_method='4DVarNet',grad=True, 
          orthographic=True,cartopy=True,figsize=(10,15))
# Out:
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/mpl/gridliner.py:336: UserWarning: The .xlabels_bottom attribute is deprecated. Please use .bottom_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_bottom attribute is deprecated. Please '
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/mpl/gridliner.py:360: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/crs.py:228: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/crs.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /linkhome/rech/genimt01/uba22to/.conda/envs/4dvarnet/lib/python3.9/site-packages/cartopy/crs.py:347: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
