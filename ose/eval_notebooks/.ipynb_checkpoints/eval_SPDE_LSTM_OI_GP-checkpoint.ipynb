# %% [markdown]
# # Prior SPDE + LSTM solver Evaluation Notebook (SPDE-based GP)

# %% [markdown]
# ## 1. Import tools and change directory

# %%
from utils_GP import *
import pandas as pd
import os

# %%
os.chdir("/users/local/m19beauc/4dvarnet-core")
print(os.getcwd())
# Out:
# /users/local/m19beauc/4dvarnet-core

# %% [markdown]
# ## 2. Run the code

# %%
# !CUDA_VISIBLE_DEVICES=0 HYDRA_FULL_ERROR=1 python hydra_main.py xp=oi_gp_spde file_paths=srv5_gp entrypoint=run entrypoint.max_epochs=50
# Out:
# /users/local/m19beauc/miniconda3/envs/4dvarnet/lib/python3.9/site-packages/hydra/_internal/hydra.py:98: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/upgrades/1.1_to_1.2/changes_to_job_working_dir for more information.
#   ret = run_job(
# Global seed set to 0
# file_paths:
#   obs_path: /users/local/m19beauc/SPDE_dc/python/SPDE_diffusion_dataset.nc
#   gt_path: /users/local/m19beauc/SPDE_dc/python/SPDE_diffusion_dataset.nc
# entrypoint:
#   _target_: hydra_main.FourDVarNetHydraRunner.run
#   max_epochs: 50
#   progress_bar_refresh_rate: 5
# params:
#   files_cfg:
#     obs_path: ${file_paths.obs_path}
#     obs_var: 'y'
#     gt_path: ${file_paths.gt_path}
#     gt_var: x
#   iter_update:
#   - 0
#   - 20
#   - 40
#   - 60
#   - 100
#   - 150
#   - 800
#   nb_grad_update:
#   - 20
#   - 20
#   - 20
#   - 20
#   - 20
#   - 20
#   - 50
#   - 50
#   - 50
#   lr_update:
#   - 0.001
#   - 0.0001
#   - 0.001
#   - 0.0001
#   - 0.0001
#   - 1.0e-05
#   - 1.0e-05
#   - 1.0e-06
#   - 1.0e-07
#   k_batch: 1
#   n_grad: 5
#   dT: 5
#   dx: 1
#   W: 100
#   resize_factor: 1
#   shapeData:
#   - 5
#   - 100
#   - 100
#   dW: 3
#   dW2: 1
#   sS: 4
#   nbBlocks: 1
#   Nbpatches: 1
#   stochastic: false
#   size_ensemble: 1
#   animate: true
#   supervised: true
#   estim_parameters: false
#   DimAE: 25
#   dim_grad_solver: 70
#   dropout: 0.25
#   dropout_phi_r: 0.0
#   alpha_proj: 0.5
#   alpha_sr: 0.5
#   alpha_lr: 0.5
#   alpha_mse_ssh: 10.0
#   alpha_mse_gssh: 1.0
#   sigNoise: 0.0
#   flagSWOTData: true
#   rnd1: 0
#   rnd2: 100
#   dwscale: 1
#   UsePriodicBoundary: false
#   InterpFlag: false
#   automatic_optimization: true
#   ckpt_name: modelGP_{epoch:02d}-{val_loss:.2f}
#   norm_obs: l2
#   norm_prior: l2
#   diff_only: true
# datamodule:
#   dim_range:
#     lat:
#       _target_: builtins.slice
#       _args_:
#       - 0
#       - 100
#     lon:
#       _target_: builtins.slice
#       _args_:
#       - 0
#       - 100
#   _target_: oi.dataloading_gp.FourDVarNetDataModule
#   slice_win:
#     lat: 100
#     lon: 100
#     time: 5
#   strides:
#     lat: 100
#     lon: 100
#     time: 1
#   train_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2012-10-01'
#     - '2012-11-20'
#   - _target_: builtins.slice
#     _args_:
#     - '2013-02-07'
#     - '2013-09-10'
#   test_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2013-01-03'
#     - '2013-01-27'
#   val_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2012-11-30'
#     - '2012-12-24'
#   obs_path: ${params.files_cfg.obs_path}
#   obs_var: ${params.files_cfg.obs_var}
#   gt_path: ${params.files_cfg.gt_path}
#   gt_var: ${params.files_cfg.gt_var}
#   dl_kwargs:
#     batch_size: 2
#     num_workers: 2
#   resize_factor: 1
# lit_mod_cls: oi.lit_model_spde.LitModel
# xp_name: oi_gp_spde
# seed: 0
#
# Using current oi.metrics
# [2022-05-03 14:34:38,283][cartopy_userconfig][INFO] - Setting cartopy.config["pre_existing_data_dir"] to /users/local/m19beauc/miniconda3/envs/4dvarnet/share/cartopy. Don't worry, this is probably intended behaviour to avoid failing downloads of geological data behind a firewall.
# file_paths:
#   obs_path: /users/local/m19beauc/SPDE_dc/python/SPDE_diffusion_dataset.nc
#   gt_path: /users/local/m19beauc/SPDE_dc/python/SPDE_diffusion_dataset.nc
# entrypoint:
#   _target_: hydra_main.FourDVarNetHydraRunner.run
#   max_epochs: 50
#   progress_bar_refresh_rate: 5
# params:
#   files_cfg:
#     obs_path: ${file_paths.obs_path}
#     obs_var: 'y'
#     gt_path: ${file_paths.gt_path}
#     gt_var: x
#   iter_update:
#   - 0
#   - 20
#   - 40
#   - 60
#   - 100
#   - 150
#   - 800
#   nb_grad_update:
#   - 20
#   - 20
#   - 20
#   - 20
#   - 20
#   - 20
#   - 50
#   - 50
#   - 50
#   lr_update:
#   - 0.001
#   - 0.0001
#   - 0.001
#   - 0.0001
#   - 0.0001
#   - 1.0e-05
#   - 1.0e-05
#   - 1.0e-06
#   - 1.0e-07
#   k_batch: 1
#   n_grad: 5
#   dT: 5
#   dx: 1
#   W: 100
#   resize_factor: 1
#   shapeData:
#   - 5
#   - 100
#   - 100
#   dW: 3
#   dW2: 1
#   sS: 4
#   nbBlocks: 1
#   Nbpatches: 1
#   stochastic: false
#   size_ensemble: 1
#   animate: true
#   supervised: true
#   estim_parameters: false
#   DimAE: 25
#   dim_grad_solver: 70
#   dropout: 0.25
#   dropout_phi_r: 0.0
#   alpha_proj: 0.5
#   alpha_sr: 0.5
#   alpha_lr: 0.5
#   alpha_mse_ssh: 10.0
#   alpha_mse_gssh: 1.0
#   sigNoise: 0.0
#   flagSWOTData: true
#   rnd1: 0
#   rnd2: 100
#   dwscale: 1
#   UsePriodicBoundary: false
#   InterpFlag: false
#   automatic_optimization: true
#   ckpt_name: modelGP_{epoch:02d}-{val_loss:.2f}
#   norm_obs: l2
#   norm_prior: l2
#   diff_only: true
# datamodule:
#   dim_range:
#     lat:
#       _target_: builtins.slice
#       _args_:
#       - 0
#       - 100
#     lon:
#       _target_: builtins.slice
#       _args_:
#       - 0
#       - 100
#   _target_: oi.dataloading_gp.FourDVarNetDataModule
#   slice_win:
#     lat: 100
#     lon: 100
#     time: 5
#   strides:
#     lat: 100
#     lon: 100
#     time: 1
#   train_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2012-10-01'
#     - '2012-11-20'
#   - _target_: builtins.slice
#     _args_:
#     - '2013-02-07'
#     - '2013-09-10'
#   test_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2013-01-03'
#     - '2013-01-27'
#   val_slices:
#   - _target_: builtins.slice
#     _args_:
#     - '2012-11-30'
#     - '2012-12-24'
#   obs_path: ${params.files_cfg.obs_path}
#   obs_var: ${params.files_cfg.obs_var}
#   gt_path: ${params.files_cfg.gt_path}
#   gt_var: ${params.files_cfg.gt_var}
#   dl_kwargs:
#     batch_size: 2
#     num_workers: 2
#   resize_factor: 1
# lit_mod_cls: oi.lit_model_spde.LitModel
# xp_name: oi_gp_spde
# seed: 0
#
# get_model:  None
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type                | Params
# -----------------------------------------------------
# 0 | model        | Solver_Grad_4DVarNN | 189 K
# 1 | model_LR     | ModelLR             | 0
# 2 | gradient_img | Gradient_img        | 18
# -----------------------------------------------------
# 189 K     Trainable params
# 23        Non-trainable params
# 189 K     Total params
# 0.759     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]/users/local/m19beauc/miniconda3/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:105: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 64 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Global seed set to 0
# /users/local/m19beauc/miniconda3/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:105: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 64 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /users/local/m19beauc/miniconda3/envs/4dvarnet/lib/python3.9/site-packages/pytorch_lightning/callbacks/lr_monitor.py:112: RuntimeWarning: You are using `LearningRateMonitor` callback with models that have no learning rate schedulers. Please see documentation for `configure_optimizers` method.
#   rank_zero_warn(
# Epoch 0:  92%|▉| 130/141 [00:30<00:02,  4.34it/s, loss=1.1, v_num=4, loss_step=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 0:  99%|▉| 140/141 [00:30<00:00,  4.57it/s, loss=1.1, v_num=4, loss_step=1
# Epoch 0: 100%|█| 141/141 [00:31<00:00,  4.50it/s, loss=1.1, v_num=4, loss_step=1
# Epoch 1:  92%|▉| 130/141 [00:29<00:02,  4.39it/s, loss=0.951, v_num=4, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 1:  99%|▉| 140/141 [00:30<00:00,  4.62it/s, loss=0.951, v_num=4, loss_step
# Epoch 1: 100%|█| 141/141 [00:31<00:00,  4.55it/s, loss=0.951, v_num=4, loss_step
# Epoch 2:  92%|▉| 130/141 [00:29<00:02,  4.42it/s, loss=0.903, v_num=4, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 2:  99%|▉| 140/141 [00:30<00:00,  4.66it/s, loss=0.903, v_num=4, loss_step
# Epoch 2: 100%|█| 141/141 [00:30<00:00,  4.59it/s, loss=0.903, v_num=4, loss_step
# Epoch 3:  92%|▉| 130/141 [00:30<00:02,  4.34it/s, loss=0.863, v_num=4, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 3:  99%|▉| 140/141 [00:30<00:00,  4.56it/s, loss=0.863, v_num=4, loss_step
# Epoch 3: 100%|█| 141/141 [00:31<00:00,  4.50it/s, loss=0.863, v_num=4, loss_step
# Epoch 4:  92%|▉| 130/141 [00:29<00:02,  4.40it/s, loss=0.855, v_num=4, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 4:  99%|▉| 140/141 [00:30<00:00,  4.63it/s, loss=0.855, v_num=4, loss_step
# Epoch 4: 100%|█| 141/141 [00:31<00:00,  4.56it/s, loss=0.855, v_num=4, loss_step
# Epoch 5:  92%|▉| 130/141 [00:29<00:02,  4.40it/s, loss=0.858, v_num=4, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 5:  99%|▉| 140/141 [00:30<00:00,  4.63it/s, loss=0.858, v_num=4, loss_step
# Epoch 5: 100%|█| 141/141 [00:31<00:00,  4.56it/s, loss=0.858, v_num=4, loss_step
# Epoch 6:  92%|▉| 130/141 [00:29<00:02,  4.39it/s, loss=0.825, v_num=4, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 6:  99%|▉| 140/141 [00:30<00:00,  4.62it/s, loss=0.825, v_num=4, loss_step
# Epoch 6: 100%|█| 141/141 [00:31<00:00,  4.55it/s, loss=0.825, v_num=4, loss_step
# Epoch 7:  92%|▉| 130/141 [00:30<00:02,  4.37it/s, loss=0.818, v_num=4, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 7:  99%|▉| 140/141 [00:30<00:00,  4.60it/s, loss=0.818, v_num=4, loss_step
# Epoch 7: 100%|█| 141/141 [00:31<00:00,  4.53it/s, loss=0.818, v_num=4, loss_step
# Epoch 8:  92%|▉| 130/141 [00:29<00:02,  4.38it/s, loss=0.816, v_num=4, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 8:  99%|▉| 140/141 [00:30<00:00,  4.61it/s, loss=0.816, v_num=4, loss_step
# Epoch 8: 100%|█| 141/141 [00:31<00:00,  4.54it/s, loss=0.816, v_num=4, loss_step
# Epoch 9:  92%|▉| 130/141 [00:29<00:02,  4.40it/s, loss=0.81, v_num=4, loss_step=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 9:  99%|▉| 140/141 [00:30<00:00,  4.63it/s, loss=0.81, v_num=4, loss_step=
# Epoch 9: 100%|█| 141/141 [00:31<00:00,  4.56it/s, loss=0.81, v_num=4, loss_step=
# Epoch 10:  92%|▉| 130/141 [00:30<00:02,  4.36it/s, loss=0.796, v_num=4, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 10:  99%|▉| 140/141 [00:30<00:00,  4.59it/s, loss=0.796, v_num=4, loss_ste
# Epoch 10: 100%|█| 141/141 [00:31<00:00,  4.52it/s, loss=0.796, v_num=4, loss_ste
# Epoch 11:  92%|▉| 130/141 [00:29<00:02,  4.41it/s, loss=0.813, v_num=4, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 11:  99%|▉| 140/141 [00:30<00:00,  4.64it/s, loss=0.813, v_num=4, loss_ste
# Epoch 11: 100%|█| 141/141 [00:31<00:00,  4.57it/s, loss=0.813, v_num=4, loss_ste
# Epoch 12:  92%|▉| 130/141 [00:29<00:02,  4.42it/s, loss=0.813, v_num=4, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 12:  99%|▉| 140/141 [00:30<00:00,  4.65it/s, loss=0.813, v_num=4, loss_ste
# Epoch 12: 100%|█| 141/141 [00:30<00:00,  4.58it/s, loss=0.813, v_num=4, loss_ste
# Epoch 13:  92%|▉| 130/141 [00:29<00:02,  4.42it/s, loss=0.79, v_num=4, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 13:  99%|▉| 140/141 [00:30<00:00,  4.65it/s, loss=0.79, v_num=4, loss_step
# Epoch 13: 100%|█| 141/141 [00:30<00:00,  4.58it/s, loss=0.79, v_num=4, loss_step
# Epoch 14:  92%|▉| 130/141 [00:29<00:02,  4.41it/s, loss=0.806, v_num=4, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 14:  99%|▉| 140/141 [00:30<00:00,  4.65it/s, loss=0.806, v_num=4, loss_ste
# Epoch 14: 100%|█| 141/141 [00:31<00:00,  4.58it/s, loss=0.806, v_num=4, loss_ste
# Epoch 15:  92%|▉| 130/141 [00:28<00:02,  4.54it/s, loss=0.799, v_num=4, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 15:  99%|▉| 140/141 [00:29<00:00,  4.78it/s, loss=0.799, v_num=4, loss_ste
# Epoch 15: 100%|█| 141/141 [00:30<00:00,  4.70it/s, loss=0.799, v_num=4, loss_ste
# Epoch 16:  92%|▉| 130/141 [00:29<00:02,  4.42it/s, loss=0.789, v_num=4, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 16:  99%|▉| 140/141 [00:30<00:00,  4.65it/s, loss=0.789, v_num=4, loss_ste
# Epoch 16: 100%|█| 141/141 [00:30<00:00,  4.58it/s, loss=0.789, v_num=4, loss_ste
# Epoch 17:  92%|▉| 130/141 [00:29<00:02,  4.42it/s, loss=0.778, v_num=4, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 17:  99%|▉| 140/141 [00:30<00:00,  4.65it/s, loss=0.778, v_num=4, loss_ste
# Epoch 17: 100%|█| 141/141 [00:30<00:00,  4.58it/s, loss=0.778, v_num=4, loss_ste
# Epoch 18:  92%|▉| 130/141 [00:29<00:02,  4.43it/s, loss=0.78, v_num=4, loss_step
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 18:  99%|▉| 140/141 [00:30<00:00,  4.66it/s, loss=0.78, v_num=4, loss_step
# Epoch 18: 100%|█| 141/141 [00:30<00:00,  4.59it/s, loss=0.78, v_num=4, loss_step
# Epoch 19:  92%|▉| 130/141 [00:29<00:02,  4.39it/s, loss=0.797, v_num=4, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 19:  99%|▉| 140/141 [00:30<00:00,  4.62it/s, loss=0.797, v_num=4, loss_ste
# Epoch 19: 100%|█| 141/141 [00:31<00:00,  4.55it/s, loss=0.797, v_num=4, loss_ste
# Epoch 20:   0%| | 0/141 [00:00<00:00, 4275.54it/s, loss=0.797, v_num=4, loss_ste... Update Iterations number/learning rate #20: NGrad = 20 -- lr = 0.000100
# Epoch 20:  92%|▉| 130/141 [01:50<00:09,  1.18it/s, loss=0.821, v_num=4, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 20:  99%|▉| 140/141 [01:52<00:00,  1.25it/s, loss=0.821, v_num=4, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:04<00:00,  2.41it/s]
# Epoch 20: 100%|█| 141/141 [01:55<00:00,  1.23it/s, loss=0.821, v_num=4, loss_ste
# Epoch 21:  92%|▉| 130/141 [01:50<00:09,  1.19it/s, loss=0.779, v_num=4, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 21:  99%|▉| 140/141 [01:52<00:00,  1.25it/s, loss=0.779, v_num=4, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:04<00:00,  2.41it/s]
# Epoch 21: 100%|█| 141/141 [01:54<00:00,  1.24it/s, loss=0.779, v_num=4, loss_ste
# Epoch 22:  92%|▉| 130/141 [01:50<00:09,  1.19it/s, loss=0.776, v_num=4, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 22:  99%|▉| 140/141 [01:52<00:00,  1.25it/s, loss=0.776, v_num=4, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:04<00:00,  2.40it/s]
# Epoch 22: 100%|█| 141/141 [01:54<00:00,  1.24it/s, loss=0.776, v_num=4, loss_ste
# Epoch 23:  92%|▉| 130/141 [01:50<00:09,  1.19it/s, loss=0.778, v_num=4, loss_ste
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/11 [00:00<?, ?it/s]
# Epoch 23:  99%|▉| 140/141 [01:52<00:00,  1.25it/s, loss=0.778, v_num=4, loss_ste
# Validating:  91%|████████████████████████████▏  | 10/11 [00:04<00:00,  2.41it/s]
# Epoch 23: 100%|█| 141/141 [01:54<00:00,  1.24it/s, loss=0.778, v_num=4, loss_ste
# Epoch 24:  50%|▍| 70/141 [00:59<00:59,  1.19it/s, loss=0.768, v_num=4, loss_step

# %% [markdown]
# # 3. Retrieve and import the results

# %%
import glob
from datetime import datetime
import numpy as np

dirs = glob.glob("/users/local/m19beauc/4dvarnet-core/dashboard/oi_gp_spde/lightning_logs/*")
file = max(dirs, key=os.path.getctime) + "/maps.nc"
print(file)

# import 4dvarNet reconstruction
data_4dvarnet = xr.open_dataset(file).isel(daw=2)
#time = [ np.datetime_as_string(date, unit='D') for date in data_4dvarnet.time.values ]
time = data_4dvarnet.Time.values

# import OI baseline
file = "/users/local/m19beauc/SPDE_dc/python/SPDE_diffusion_dataset.nc"
data_baseline = xr.open_dataset(file)
data_baseline['time'] = pd.date_range(start="2012-10-01", periods=data_baseline.sizes['time'], freq='D')
data_baseline = data_baseline.sel(time=slice(time[0],time[-1]))

# rename variables
data_baseline = data_baseline.update({
                     'gt':(('time','lat','lon'),data_4dvarnet.gt.values),
                     'obs_inp':(('time','lat','lon'),data_4dvarnet.obs.values),
                     'pred':(('time','lat','lon'),data_baseline.OI.values)})
data_4dvarnet = data_4dvarnet.update({
                     'obs_inp':(('time','lat','lon'),
                                np.where(data_4dvarnet.obs.values==np.median(data_4dvarnet.obs.values),np.nan,data_4dvarnet.obs.values))})
# Out:
# /users/local/m19beauc/4dvarnet-core/dashboard/oi_gp_spde/lightning_logs/version_3/maps.nc

# %% [markdown]
# ## 2. Compute RMSE-based scores

# %%
rmse_t_pred_baseline, rmse_xy_pred_baseline, nrmse_pred_baseline, nrmse_std_pred_baseline = rmse_based_scores(data_baseline,'pred')
rmse_t_pred_4dvarnet, rmse_xy_pred_4dvarnet, nrmse_pred_4dvarnet, nrmse_std_pred_4dvarnet = rmse_based_scores(data_4dvarnet,'pred')

# %% [markdown]
# ## 3. Compute spectral scores

# %%
# %matplotlib inline  

ds_psd_pred_baseline, lambda_x_pred_baseline, lambda_t_pred_baseline = psd_based_scores(data_baseline,'pred',dx=1,dt=1)
ds_psd_pred_4dvarnet, lambda_x_pred_4dvarnet, lambda_t_pred_4dvarnet = psd_based_scores(data_4dvarnet,'pred',dx=1,dt=1)

psd_concat = xr.concat((ds_psd_pred_4dvarnet, ds_psd_pred_baseline), dim='experiment')
psd_concat['experiment'] = ["4dvarnet","baseline"]
plot_psd_score(psd_concat,dx=1,dt=1)
# Out:
# [#                                       ] | 2% Completed |  0.1s
# /users/local/m19beauc/miniconda3/envs/4dvarnet/lib/python3.9/site-packages/xrft/xrft.py:49: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# [########################################] | 100% Completed |  1.1s
# [#                                       ] | 4% Completed |  0.1s
# /users/local/m19beauc/miniconda3/envs/4dvarnet/lib/python3.9/site-packages/xrft/xrft.py:49: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# [########################################] | 100% Completed |  1.0s
# [##                                      ] | 5% Completed |  0.1s
# /users/local/m19beauc/miniconda3/envs/4dvarnet/lib/python3.9/site-packages/xrft/xrft.py:49: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# [########################################] | 100% Completed |  1.0s
# [#                                       ] | 4% Completed |  0.1s
# /users/local/m19beauc/miniconda3/envs/4dvarnet/lib/python3.9/site-packages/xrft/xrft.py:49: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# [########################################] | 100% Completed |  1.2s

# %% [markdown]
# ## 4. Export RMSE and spectral scores

# %%
tab_score = pd.DataFrame(dict(name=['4dVarnet',"baseline"],
                  mu_RMSE=[nrmse_pred_4dvarnet,nrmse_pred_baseline],
                  std_RMSE=[nrmse_std_pred_4dvarnet,nrmse_std_pred_baseline],
                  lambda_x_degree=[lambda_x_pred_4dvarnet,lambda_x_pred_baseline],
                  lambda_t_days=[lambda_t_pred_4dvarnet,lambda_t_pred_baseline],
                  Notes = ['4dvarnet','baseline']))
tab_score
# Out:
#        name  mu_RMSE  std_RMSE  lambda_x_degree  lambda_t_days     Notes
# 0  4dVarnet     0.24      0.05            32.14          18.80  4dvarnet
# 1  baseline     0.31      0.04            26.61          17.21  baseline

# %% [markdown]
# ## 5. Display nRMSE time series on the test period

# %%
TS(list_data=[data_baseline.gt.values,data_baseline.obs_inp.values,
              data_baseline.pred.values, data_4dvarnet.pred.values],
   labels_data=np.array(['GT','Obs', 'OI (baseline)', '4DVarNet']),
   colors=np.array(['k','','red','seagreen']),
   symbols=np.array(['k','','o','o']),
   lstyle=np.array(['solid','','solid','solid']),lwidth = np.array([2,2,2,2]),
   dt=1,
   gradient=False)

# %% [markdown]
# ## 6. Display raw and gradient fields

# %%
itime = 20
plot_maps(data_baseline.gt[itime].values,data_baseline.obs_inp[itime].values,
          [data_baseline.pred[itime].values,data_4dvarnet.pred[itime].values],[],
          data_baseline.lon,data_baseline.lat,new_method='4DVarNet',grad=False, 
          orthographic=True,cartopy=False,figsize=(10,15))

# %%
plot_maps(data_baseline.gt[itime].values,data_baseline.obs_inp[itime].values,
          [data_baseline.pred[itime].values,data_4dvarnet.pred[itime].values],[],
          data_baseline.lon,data_baseline.lat,new_method='4DVarNet',grad=True, 
          orthographic=True,cartopy=False,figsize=(10,15))
